# %%
import matplotlib
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import datetime
import pytz
from pytz import timezone
#import squarify

# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)
saved_style_state = matplotlib.rcParams.copy() 
plt.rc('font', family = "gotham", weight = "bold")
plt.rc("axes", grid = True, titleweight = "bold", labelweight = "bold")
plt.rc("axes.grid", axis = "y")

# %%
c1 = "#8bb8e8"
c2 = "#95a3ce"
c3 = "#9f8eb3"
c4 = "#b4657f"
c5 = "#a97999"
c6 = "#be5065"
c7 = "#c83b4a"
c8 = "#d22630"
colourmap = [c1,c2,c3,c4,c5,c6,c7,c8]

l1 = "#B8DDE1"
l2 = "#9BD3DD"
l3 = "#77C5D5"
l4 = "#3EB1C8"
l5 = "#0093B2"
l6 = "#007396"
lblueshades = [l1,l2,l3,l4,l5,l6]

# %%
filepath = r"C:\Users\user\Documents\THESIS\Results\Test 1\RCP_10_BM.csv"

print("Opening File...")
benchmark = pd.read_csv(filepath, header = 0)

filepath = r"C:\Users\user\Documents\THESIS\Results\Test 1\csvs\RCP_10_Cluster.csv"

cluster1 = pd.read_csv(filepath, header = 0)

filepath = r"C:\Users\user\Documents\THESIS\Results\Test 1\csvs\RCP_10_PostCluster.csv"

cluster2 = pd.read_csv(filepath, header = 0)
# Out:
# Opening File...

# %%
def box1():
    #BMframe = pd.DataFrame(benchmark["Time"])
    C1frame = [cluster1["Time"], cluster1["BMTime"]]
    C1.shape = (-1,1)
    fig, ax = plt.subplots()
    #BMframe.boxplot(showfliers = True, boxprops = dict(linewidth = 4), whiskerprops = dict(linewidth = 2), medianprops = dict(linewidth = 2), capprops = dict(linewidth = 2))
    #C1frame.boxplot(showfliers = True, boxprops = dict(linewidth = 4), whiskerprops = dict(linewidth = 2), medianprops = dict(linewidth = 2), capprops = dict(linewidth = 2))
    C1frame.boxplot(data)
    plt.title("RCP_10 - Benchmark - Time", fontsize = 18)
    plt.ylabel("Time (Seconds)", fontsize = 14)
    #fig, ax = plt.subplots()
    #ax.boxplot(BMframe)
    plt.show()


box1()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-81a7cab6a3f3> in <module>
#      13
#      14
# ---> 15 box1()
#
# <ipython-input-18-81a7cab6a3f3> in box1()
#       5     #BMframe.boxplot(showfliers = True, boxprops = dict(linewidth = 4), whiskerprops = dict(linewidth = 2), medianprops = dict(linewidth = 2), capprops = dict(linewidth = 2))
#       6     #C1frame.boxplot(showfliers = True, boxprops = dict(linewidth = 4), whiskerprops = dict(linewidth = 2), medianprops = dict(linewidth = 2), capprops = dict(linewidth = 2))
# ----> 7     C1frame.boxplot(data)
#       8     plt.title("RCP_10 - Benchmark - Time", fontsize = 18)
#       9     plt.ylabel("Time (Seconds)", fontsize = 14)
#
# AttributeError: 'list' object has no attribute 'boxplot'

# %%
def box2():
    x = results["Objective"]
    frame = pd.DataFrame(x)

    frame.boxplot(showfliers = True, boxprops = dict(linewidth = 4), whiskerprops = dict(linewidth = 2), medianprops = dict(linewidth = 2), capprops = dict(linewidth = 2))
    plt.title("RCP_10 - Benchmark - Objective", fontsize = 18)
    plt.ylabel("Objective", fontsize = 14)
    plt.show()

# %%
box1()
box2()
# Out:
# <ipython-input-7-e5cfcdc3cc0b>:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot()
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-22c56ffc05a3> in <module>
#       1 box1()
# ----> 2 box2()
#
# NameError: name 'box2' is not defined
